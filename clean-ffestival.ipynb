# %%
import pandas as pd

# %%
pd.read_csv('combined_film_oscars.csv')
# Out:
# /var/folders/j5/twx6v7jj4nq17ymrbt5c1klw0000gn/T/ipykernel_89176/99386385.py:1: DtypeWarning: Columns (16,42,43,44,45,46,47,48,49,75,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('combined_film_oscars.csv')
#          film.id unique.id  sample.year       fest  \
# 0          f2081         1         2013     CANNES
# 1      tffnew391        10         2012       TIFF
# 2          f2023        10         2013     CANNES
# 3          f1160       100         2013  BERLINALE
# 4          f1285      1000         2013  BERLINALE
# ...          ...       ...          ...        ...
# 10374   tffnew95  tffnew95         2011       TIFF
# 10375   tffnew96  tffnew96         2011       TIFF
# 10376   tffnew97  tffnew97         2011       TIFF
# 10377   tffnew98  tffnew98         2011       TIFF
# 10378   tffnew99  tffnew99         2011       TIFF
#
#                                           fest.sect    imdb.id  \
# ...

# %%
pd.read_csv('oscars_2019.csv')
# Out:
#      Ceremony  Year    Class  \
# 0          92  2019   Acting
# 1          92  2019   Acting
# 2          92  2019   Acting
# 3          92  2019   Acting
# 4          92  2019   Acting
# ..        ...   ...      ...
# 140        92  2019  SciTech
# 141        92  2019  SciTech
# 142        92  2019  SciTech
# 143        92  2019  SciTech
# 144        92  2019  SciTech
#
#                                      CanonicalCategory  \
# 0                              ACTOR IN A LEADING ROLE
# 1                              ACTOR IN A LEADING ROLE
# 2                              ACTOR IN A LEADING ROLE
# 3                              ACTOR IN A LEADING ROLE
# 4                              ACTOR IN A LEADING ROLE
# ..                                                 ...
# 140  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 141  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# 142  SCIENTIFIC AND TECHNICAL AWARD (Technical Achi...
# ...
